# %%
import sys

sys.path.append("..")

from kandinsky3 import get_T2I_pipeline

# %%
t2i_pipe = get_T2I_pipeline(
    "cuda:0", fp16=True, cache_dir="D:\\workspace\\sd-model\\kandinsky"
)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
res = t2i_pipe(
    "a Japanese 1980s anime of a male anthro panda with bright and watery eyes, wearing baggy clothing and rubber boots, gentle smiling and looking at viewer, standing in rain at train station, the sky is grey and distance fog, the floor is wet with ripples",
    seed=1234,
)
# Out:
# VRAM Usage (Before T5 encoder): Total: 24146083840 | Reserved: 2097152 | Allocated: 2048
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# bin C:\Users\SLAPaper\scoop\apps\miniconda3\current\envs\sd_webui\lib\site-packages\bitsandbytes\libbitsandbytes_cuda121.dll
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# VRAM Usage (After T5 encoder): Total: 24146083840 | Reserved: 8610906112 | Allocated: 8260398592
# VRAM Usage (After T5 encoder deletion): Total: 24146083840 | Reserved: 25165824 | Allocated: 9538048
# VRAM Usage (Before UNet): Total: 24146083840 | Reserved: 25165824 | Allocated: 9538048
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:06<00:00,  7.76it/s]
# VRAM Usage (After UNet): Total: 24146083840 | Reserved: 14864613376 | Allocated: 6167561728
# ...

# %%
res[0]
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
res[0].save("../output/panda6.png")
